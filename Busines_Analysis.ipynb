# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df= pd.read_csv('supermarket_sales.csv')

# %%
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
df.shape
# Out:
# (1000, 17)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %% [markdown]
# ##### Some objects for Dtype and float64 or int64

# %%
df.isnull().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Basic exploration of Data
# * No Null Values
# * NO duplicated Values
#
# #
# #
# #

# %%
df.head(3)
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total      Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715  1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200  3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255  3/3/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# 1  10:29         Cash   76.40                 4.761905        3.8200     9.6
# 2  13:23  Credit card  324.31                 4.761905       16.2155     7.4

# %%
# Created some cols for date col ex.. day, month, year
df['Date'] = pd.to_datetime(df['Date'])
df['Date'].dtype

df['day'] = df['Date'].dt.day
df['month'] = df['Date'].dt.month
df['year']= df['Date'].dt.year

# check-up
df.head()

#don't need date and Date
# del(df['Date'])
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715 2019-01-05
# 1  Electronic accessories       15.28         5   3.8200   80.2200 2019-03-08
# 2      Home and lifestyle       46.33         7  16.2155  340.5255 2019-03-03
# 3       Health and beauty       58.22         8  23.2880  489.0480 2019-01-27
# 4       Sports and travel       86.31         7  30.2085  634.3785 2019-02-08
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating  \
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total   Time  \
# 0       Health and beauty       74.69         7  26.1415  548.9715  13:08
# 1  Electronic accessories       15.28         5   3.8200   80.2200  10:29
# 2      Home and lifestyle       46.33         7  16.2155  340.5255  13:23
# 3       Health and beauty       58.22         8  23.2880  489.0480  20:33
# 4       Sports and travel       86.31         7  30.2085  634.3785  10:37
#
#        Payment    cogs  gross margin percentage  gross income  Rating  day  \
# 0      Ewallet  522.83                 4.761905       26.1415     9.1    5
# ...

# %%
df['Time'] = pd.to_datetime(df['Time'])
df['Hour'] = df['Time'].dt.hour

# %%
categorical_col = [colname for colname in df.columns if df[colname].dtype == 'object']
categorical_col
# Out:
# ['Invoice ID',
#  'Branch',
#  'City',
#  'Customer type',
#  'Gender',
#  'Product line',
#  'Payment']

# %% [markdown]
# ## Data Visualization

# %%
sns.countplot(data = df, x = 'Gender')

# %%
sns.boxplot(data = df, x = 'Branch', y = 'Rating')
plt.title('Ratings by Branch')

# Branch B has less average than Branch A and C
# Out:
# Text(0.5, 1.0, 'Ratings by Branch')

# %%
plt.figure(figsize = (15,5))
df2 = df[['Product line','Rating']].groupby(['Product line'], as_index = False).mean().sort_values(by = 'Rating', ascending = False)
sns.barplot(data = df2, x = 'Product line', y = 'Rating')
plt.title("Average Rating by Product line",fontdict={'fontsize': 20})
# Out:
# Text(0.5, 1.0, 'Average Rating by Product line')

# %% [markdown]
# Can't find a thing from average rating by product line

# %%
plt.figure(figsize = (15,5))
df3 = df[['Product line','gross income']].groupby(['Product line'], as_index = False).sum().sort_values(by = 'gross income', ascending = False)
sns.barplot(data = df3, x = 'Product line', y = 'gross income')
plt.title('Total Gross Income by Product line',fontdict={'fontsize': 20})
# Out:
# Text(0.5, 1.0, 'Total Gross Income by Product line')

# %% [markdown]
# The highest gross income is from Food and Beverage.
# The lowest gross income is from Health and Beauty

# %%
sns.lineplot(data = df, x = 'Hour', y = 'Quantity')
plt.title('Product Sales per Hour',fontdict={'fontsize': 20})
# Out:
# Text(0.5, 1.0, 'Product Sales per Hour')

# %% [markdown]
# The highest peak is 14 hour

# %%
sns.relplot(data = df, x = 'Hour', y = 'Quantity', col = 'month', row ='Branch', kind = 'line', hue = 'Gender')

# %%
sns.boxenplot(data = df, x = 'Quantity', y = 'Product line')

# %% [markdown]
# Product line in Fasion accessories and Food and Beverages has less average quanitity compared to others <br>
# However, Fashion accessories and Food and Beverage has the high average review rating

# %%
sns.barplot(data = df, x= 'Branch',y = 'gross income')
plt.xlabel('Branch Code / Branch Name', fontsize = '12')
plt.ylabel('Gross Income', fontsize = '12')
plt.title('Most Profittable Centre Judgement',fontdict={'fontsize': 20})
# Out:
# Text(0.5, 1.0, 'Most Profittable Centre Judgement')

# %%
sns.barplot(data = df, x= 'City',y = 'gross income')
plt.xlabel('City', fontsize = '12')
plt.ylabel('Gross Income', fontsize = '12')
plt.title('Most Profittable Centre Judgement',fontdict={'fontsize': 20})
# Out:
# Text(0.5, 1.0, 'Most Profittable Centre Judgement')

# %%
sns.countplot(data= df, y = 'Product line', order = df['Product line'].value_counts().index )

# %%
plt.figure(figsize = (12,8))

sns.boxenplot(data = df, x = 'Rating', y = 'Product line')

# %%
sns.countplot(data = df, x = 'Payment')
plt.title('Payment Mode')
# Out:
# Text(0.5, 1.0, 'Payment Mode')

# %% [markdown]
# Ewallet and Cashpayment is higher than credit card

# %%
sns.countplot(data = df, x = 'Payment', hue = 'Branch')
plt.title('Payment Mode by Branch')
# Out:
# Text(0.5, 1.0, 'Payment Mode by Branch')

# %% [markdown]
# ## Customer Analysis

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total  ...  \
# 0       Health and beauty       74.69         7  26.1415  548.9715  ...
# 1  Electronic accessories       15.28         5   3.8200   80.2200  ...
# 2      Home and lifestyle       46.33         7  16.2155  340.5255  ...
# 3       Health and beauty       58.22         8  23.2880  489.0480  ...
# 4       Sports and travel       86.31         7  30.2085  634.3785  ...
#
#                  Time      Payment    cogs  gross margin percentage  \
# 0 2022-06-30 13:08:00      Ewallet  522.83                 4.761905
# ...

# %%
sns.countplot(data = df, x = 'Customer type', hue = 'Branch')

# %%
df.groupby(['Customer type'])['Total'].sum()
# Out:
# Customer type
# Member    164223.444
# Normal    158743.305
# Name: Total, dtype: float64

# %%
plt.figure(figsize = (8,8))
sns.swarmplot(data = df, x = 'Customer type',y = 'Rating', hue = 'City')
plt.title('Customer type by Rating')
# Out:
# Text(0.5, 1.0, 'Customer type by Rating')

# %%
plt.figure(figsize = (10,5))
sns.lmplot(data = df, x = 'Unit price', y = 'gross income')
plt.title('Unit Price vs Gross Income')
# Out:
# Text(0.5, 1.0, 'Unit Price vs Gross Income')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 21 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   datetime64[ns]
#  11  Time                     1000 non-null   datetime64[ns]
#  12  Payment                  1000 non-null   object
# ...

# %%
numerical = ['cogs','Quantity','gross income','Total']

# %%
plt.figure(figsize = (20,10))
df[numerical].hist(bins = 30)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fb42ad14cd0>,
# ...
#       dtype=object)

# %%
sns.countplot(data = df, y = 'Product line',hue = 'City')

# %%
sns.countplot(data = df, y = df['Product line'].sort_values(),hue = 'City')

# %% [markdown]
# Naypyitaw leads in Food and Beverages and Fashin Accessories <br>
# Yangon leads in Electronic Accessories<br>
# Mandalay leads in Sports and travel

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total  ...  \
# 0       Health and beauty       74.69         7  26.1415  548.9715  ...
# 1  Electronic accessories       15.28         5   3.8200   80.2200  ...
# 2      Home and lifestyle       46.33         7  16.2155  340.5255  ...
# 3       Health and beauty       58.22         8  23.2880  489.0480  ...
# 4       Sports and travel       86.31         7  30.2085  634.3785  ...
#
#                  Time      Payment    cogs  gross margin percentage  \
# 0 2022-06-30 13:08:00      Ewallet  522.83                 4.761905
# ...

# %%
df.iloc[:,-8]
# Out:
# 0      522.83
# 1       76.40
# 2      324.31
# 3      465.76
# 4      604.17
#         ...
# 995     40.35
# 996    973.80
# 997     31.84
# 998     65.82
# 999    618.38
# Name: cogs, Length: 1000, dtype: float64

# %%
df.iloc[:,-8].values.reshape(-1,1)
# Out:
# array([[522.83],
#        [ 76.4 ],
#        [324.31],
#        [465.76],
#        [604.17],
#        [597.73],
#        [413.04],
#        [735.6 ],
#        [ 72.52],
#        [164.52],
#        [ 57.92],
#        [102.04],
#        [234.75],
#        [431.9 ],
#        [713.8 ],
#        [562.32],
#        [482.51],
#        [435.66],
#        [164.01],
#        [ 80.6 ],
#        [430.2 ],
#        [263.94],
#        [ 66.4 ],
#        [172.8 ],
#        [265.89],
#        [420.72],
#        [ 33.52],
#        [175.34],
#        [441.8 ],
#        [224.01],
#        [470.65],
#        [702.63],
#        [670.24],
#        [193.16],
#        [397.68],
#        [ 68.12],
#        [313.1 ],
#        [547.92],
#        [439.36],
#        [240.96],
#        [ 86.72],
#        [112.22],
#        [414.72],
#        [789.6 ],
#        [ 30.74],
#        [375.84],
#        [510.21],
#        [180.09],
#        [113.58],
#        [826.3 ],
#        [639.8 ],
#        [222.95],
# ...

# %%
from sklearn.model_selection import train_test_split
# cogs to Hour
X = df.iloc[:,-8].values.reshape(-1,1)

from sklearn.cluster import KMeans
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 42)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)
plt.figure(figsize=(20,7))
plt.plot(range(1, 11), wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
kmeans = KMeans(n_clusters=6, init = 'k-means++', random_state = 101)
y_kmeans = kmeans.fit_predict(X)

# %%
plt.figure(figsize=(20,8))
plt.scatter(X[y_kmeans == 0,0], X[y_kmeans == 0], s = 100, c = 'red')
plt.scatter(X[y_kmeans == 1,0], X[y_kmeans == 1], s = 100, c = 'blue')
plt.scatter(X[y_kmeans == 2,0], X[y_kmeans == 2], s = 100, c = 'green')
plt.scatter(X[y_kmeans == 3,0], X[y_kmeans == 3], s = 100, c = 'cyan')
plt.scatter(X[y_kmeans == 4,0], X[y_kmeans == 4], s = 100, c = 'magenta')
plt.scatter(X[y_kmeans == 5,0], X[y_kmeans == 5], s = 100, c = 'k')
plt.title('Clusters of customers')
plt.xlabel('Total expenditure')
plt.ylabel('COGs earned')
plt.show()

# %% [markdown]
# Green : cluster where economically lower class of customers
# Blue : cluster where economically second lower class of customers
# Magenta : cluster where economically third lower class of customers
# Red : cluster where economically 4th class of customers
# Black : cluster where economically 5th class of customers
# Cyan :cluster where economically 6th class of customers
